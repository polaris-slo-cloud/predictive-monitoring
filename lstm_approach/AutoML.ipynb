# %% [markdown]
# # AutoML multi-step-ahead prediction

# %% [markdown]
# This notebook explores how to predict the previously defined high-level metric *Efficiency*.
# The code wraps up the data processing, the model training and testing phases, and the model export.
# Here we use RIM

# %% [markdown]
# ## Imports

# %%
import sys
from math import sqrt
import numpy as np
from numpy import array

from scipy.signal import savgol_filter

from sklearn.metrics import mean_squared_error

import pandas as pd

from matplotlib import pyplot

from gcd_data_manipulation import data_aggregation
from gcd_data_manipulation import load_data
from gcd_data_manipulation import scale_values
from gcd_data_manipulation import series_to_supervised
from gcd_data_manipulation import reshape_data

from multistepahead_model_evaluation import evaluate_forecast
from multistepahead_model_evaluation import walk_forward_validation

# %% [markdown]
# ## Data preprocessing

# %%
JOBID = 3418339

columns_to_consider = [
    "end time",
    "CPU rate",
    "canonical memory usage",
    "assigned memory usage",
    "unmapped page cache",
    "total page cache",
    "maximum memory usage",
    "disk I/O time",
    "local disk space usage",
    "maximum CPU rate",
    "maximum disk IO time",
    "cycles per instruction",
    "memory accesses per instruction",
    "Efficiency",  # target metric
]

readings_df = load_data(
    "../data/task-usage_job-ID-%i_total.csv" % JOBID, columns_to_consider
)

# %%
readings_df.head(10)
# Out:
#      end time  CPU rate  canonical memory usage  assigned memory usage  \
# 13  900000000   0.03418                 0.08752                0.09839
# 14  900000000   0.03528                 0.08740                0.09900
# 15  900000000   0.03644                 0.08704                0.09912
# 16  900000000   0.03845                 0.08728                0.09912
# 17  900000000   0.03790                 0.08716                0.09912
# 18  900000000   0.03406                 0.08704                0.09912
# 19  900000000   0.03699                 0.08704                0.09912
# 20  900000000   0.03271                 0.08704                0.09912
# 21  900000000   0.03540                 0.08704                0.09900
# 22  900000000   0.03467                 0.08716                0.09912
#
#     unmapped page cache  total page cache  maximum memory usage  \
# 13             0.001888          0.002773               0.08887
# 14             0.000626          0.001501               0.08862
# 15             0.000799          0.001247               0.08862
# 16             0.000713          0.001493               0.08850
# 17             0.000880          0.001490               0.08838
# 18             0.001905          0.002449               0.08838
# 19             0.000817          0.001331               0.08850
# 20             0.001007          0.001562               0.08838
# 21             0.001642          0.002132               0.08838
# 22             0.002350          0.002960               0.08875
#
#     disk I/O time  local disk space usage  maximum CPU rate  \
# 13       0.000274                0.000212            0.1030
# 14       0.000224                0.000215            0.1229
# 15       0.000242                0.000352            0.1141
# 16       0.000192                0.000215            0.1082
# 17       0.000077                0.000359            0.1155
# 18       0.000076                0.000349            0.1353
# 19       0.000194                0.000358            0.1348
# 20       0.000100                0.000359            0.1173
# 21       0.000109                0.000216            0.1107
# 22       0.000093                0.000358            0.1248
#
#     maximum disk IO time  cycles per instruction  \
# 13              0.057860                   1.859
# 14              0.022710                   1.976
# 15              0.030360                   1.947
# 16              0.029720                   1.913
# 17              0.004997                   2.047
# 18              0.014010                   1.820
# 19              0.035400                   1.894
# 20              0.011510                   1.690
# 21              0.011220                   2.029
# 22              0.009567                   1.900
#
#     memory accesses per instruction  Efficiency
# 13                         0.003949    0.439211
# 14                         0.004837    0.441883
# 15                         0.004163    0.495868
# 16                         0.004048    0.447112
# 17                         0.004314    0.501464
# 18                         0.003891    0.490515
# 19                         0.003909    0.499052
# 20                         0.003473    0.491831
# 21                         0.004776    0.441225
# 22                         0.004520    0.495335

# %% [markdown]
# ### Generate timestamp to interpolate NaN

# %% [markdown]
# In this part, we are taking the end time of the observation period, and we are converting them to datetime values.
# As start time, we consider the 1st of May, 2011, PT. We add this value to the end time values.

# %%
readings_df["datetime"] = timestamps_readings = [
    pd.Timestamp(int(t / 1000000) + 1304233200, tz="US/Pacific", unit="s")
    for t in readings_df["end time"].values
]

# %% [markdown]
# Here, we are setting the datetime column as index,as needed by the interpolate function from pandas

# %%
readings_df.set_index("datetime", inplace=True)

# %%
readings_df.head()
# Out:
#                             end time  CPU rate  canonical memory usage  \
# datetime
# 2011-05-01 00:15:00-07:00  900000000   0.03418                 0.08752
# 2011-05-01 00:15:00-07:00  900000000   0.03528                 0.08740
# 2011-05-01 00:15:00-07:00  900000000   0.03644                 0.08704
# 2011-05-01 00:15:00-07:00  900000000   0.03845                 0.08728
# 2011-05-01 00:15:00-07:00  900000000   0.03790                 0.08716
#
#                            assigned memory usage  unmapped page cache  \
# datetime
# 2011-05-01 00:15:00-07:00                0.09839             0.001888
# 2011-05-01 00:15:00-07:00                0.09900             0.000626
# 2011-05-01 00:15:00-07:00                0.09912             0.000799
# 2011-05-01 00:15:00-07:00                0.09912             0.000713
# 2011-05-01 00:15:00-07:00                0.09912             0.000880
#
#                            total page cache  maximum memory usage  \
# datetime
# 2011-05-01 00:15:00-07:00          0.002773               0.08887
# 2011-05-01 00:15:00-07:00          0.001501               0.08862
# 2011-05-01 00:15:00-07:00          0.001247               0.08862
# 2011-05-01 00:15:00-07:00          0.001493               0.08850
# 2011-05-01 00:15:00-07:00          0.001490               0.08838
#
#                            disk I/O time  local disk space usage  \
# datetime
# 2011-05-01 00:15:00-07:00       0.000274                0.000212
# 2011-05-01 00:15:00-07:00       0.000224                0.000215
# 2011-05-01 00:15:00-07:00       0.000242                0.000352
# 2011-05-01 00:15:00-07:00       0.000192                0.000215
# 2011-05-01 00:15:00-07:00       0.000077                0.000359
#
#                            maximum CPU rate  maximum disk IO time  \
# datetime
# 2011-05-01 00:15:00-07:00            0.1030              0.057860
# 2011-05-01 00:15:00-07:00            0.1229              0.022710
# 2011-05-01 00:15:00-07:00            0.1141              0.030360
# 2011-05-01 00:15:00-07:00            0.1082              0.029720
# 2011-05-01 00:15:00-07:00            0.1155              0.004997
#
#                            cycles per instruction  \
# datetime
# 2011-05-01 00:15:00-07:00                   1.859
# 2011-05-01 00:15:00-07:00                   1.976
# 2011-05-01 00:15:00-07:00                   1.947
# 2011-05-01 00:15:00-07:00                   1.913
# 2011-05-01 00:15:00-07:00                   2.047
#
#                            memory accesses per instruction  Efficiency
# datetime
# 2011-05-01 00:15:00-07:00                         0.003949    0.439211
# 2011-05-01 00:15:00-07:00                         0.004837    0.441883
# 2011-05-01 00:15:00-07:00                         0.004163    0.495868
# 2011-05-01 00:15:00-07:00                         0.004048    0.447112
# 2011-05-01 00:15:00-07:00                         0.004314    0.501464

# %% [markdown]
# Use interpolation to remove nan. Sources:
# - https://stackoverflow.com/questions/49308530/missing-values-in-time-series-in-python
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.interpolate.html

# %%
readings_df.interpolate(method="time", limit_direction="both", inplace=True)

# %%
readings_df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Aggregate data

# %%
def q95(x):
    return x.quantile(0.95)

def q75(x):
    return x.quantile(0.75)

def q25(x):
    return x.quantile(0.25)

# %%
readings_df_x = readings_df.groupby('end time').agg([('mean', 'mean'), ('median', 'median'), ('min', 'min'), ('max','max'), ('q25', q25), ('q75', q75), ('q95', q95), ('std', 'std')])

# %%
readings_df_x
# Out:
#                CPU rate                                               \
#                    mean   median      min      max      q25      q75
# end time
# 900000000      0.035042  0.03528  0.02972  0.03900  0.03406  0.03674
# 1200000000     0.033072  0.03326  0.02786  0.03711  0.03149  0.03491
# 1500000000     0.032797  0.03284  0.02838  0.03650  0.03131  0.03455
# 1800000000     0.032152  0.03198  0.02753  0.03717  0.03064  0.03363
# 2100000000     0.032904  0.03235  0.02805  0.03796  0.03174  0.03424
# ...                 ...      ...      ...      ...      ...      ...
# 2505000000000  0.037400  0.03735  0.03320  0.04242  0.03577  0.03906
# 2505300000000  0.036892  0.03687  0.03253  0.04059  0.03485  0.03864
# 2505600000000  0.035126  0.03442  0.03107  0.04034  0.03314  0.03687
# 2505900000000  0.035702  0.03528  0.03186  0.04419  0.03339  0.03662
# 2506200000000  0.036736  0.03644  0.03278  0.04596  0.03436  0.03802
#
#                                   canonical memory usage           ...  \
#                     q95       std                   mean   median  ...
# end time                                                           ...
# 900000000      0.038340  0.002287               0.087198  0.08716  ...
# 1200000000     0.036512  0.002358               0.086914  0.08691  ...
# 1500000000     0.036214  0.002347               0.086879  0.08691  ...
# 1800000000     0.035912  0.002360               0.086869  0.08691  ...
# 2100000000     0.037402  0.002395               0.087110  0.08704  ...
# ...                 ...       ...                    ...      ...  ...
# 2505000000000  0.040818  0.002506               0.086642  0.08655  ...
# 2505300000000  0.040384  0.002328               0.086651  0.08667  ...
# 2505600000000  0.039272  0.002597               0.086642  0.08655  ...
# 2505900000000  0.040454  0.002911               0.086642  0.08655  ...
# 2506200000000  0.042044  0.003088               0.086642  0.08655  ...
#
#               memory accesses per instruction           Efficiency            \
#                                           q95       std       mean    median
# end time
# 900000000                            0.004750  0.000411   0.481978  0.492248
# 1200000000                           0.004434  0.000320   0.477496  0.486884
# 1500000000                           0.004468  0.000350   0.476892  0.487241
# 1800000000                           0.004500  0.000300   0.475728  0.486597
# 2100000000                           0.004728  0.000462   0.477995  0.489115
# ...                                       ...       ...        ...       ...
# 2505000000000                        0.004291  0.000339   0.491919  0.496250
# 2505300000000                        0.004219  0.000342   0.491032  0.495129
# 2505600000000                        0.004291  0.000407   0.487893  0.491817
# 2505900000000                        0.004413  0.000455   0.488857  0.492573
# 2506200000000                        0.004469  0.000413   0.490708  0.494102
#
#
#                     min       max       q25       q75       q95       std
# end time
# 900000000      0.436230  0.503013  0.485122  0.498103  0.501044  0.023814
# 1200000000     0.432434  0.498235  0.480615  0.493086  0.497185  0.023934
# 1500000000     0.432217  0.497277  0.481486  0.492368  0.496901  0.024443
# 1800000000     0.430512  0.498584  0.479975  0.492232  0.496808  0.025237
# 2100000000     0.434463  0.500457  0.481746  0.494727  0.499674  0.024773
# ...                 ...       ...       ...       ...       ...       ...
# 2505000000000  0.438190  0.505653  0.490819  0.499660  0.503278  0.016719
# 2505300000000  0.437909  0.502709  0.489853  0.499242  0.502358  0.015752
# 2505600000000  0.435112  0.501935  0.485824  0.495321  0.498864  0.016324
# 2505900000000  0.434898  0.508393  0.488486  0.496057  0.501247  0.016594
# 2506200000000  0.436032  0.511926  0.489795  0.497753  0.504535  0.016947
#
# [8352 rows x 104 columns]

# %%
readings_df_x.isna().sum().sum()
# Out:
# 0

# %%
readings_df = readings_df_x[columns_to_consider[1:-1]]
readings_df["Efficiency"] = readings_df_x["Efficiency"]["mean"].values
readings_df
# Out:
# /tmp/ipykernel_1643509/2794251573.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   readings_df["Efficiency"] = readings_df_x["Efficiency"]["mean"].values
#                CPU rate                                               \
#                    mean   median      min      max      q25      q75
# end time
# 900000000      0.035042  0.03528  0.02972  0.03900  0.03406  0.03674
# 1200000000     0.033072  0.03326  0.02786  0.03711  0.03149  0.03491
# 1500000000     0.032797  0.03284  0.02838  0.03650  0.03131  0.03455
# 1800000000     0.032152  0.03198  0.02753  0.03717  0.03064  0.03363
# 2100000000     0.032904  0.03235  0.02805  0.03796  0.03174  0.03424
# ...                 ...      ...      ...      ...      ...      ...
# 2505000000000  0.037400  0.03735  0.03320  0.04242  0.03577  0.03906
# 2505300000000  0.036892  0.03687  0.03253  0.04059  0.03485  0.03864
# 2505600000000  0.035126  0.03442  0.03107  0.04034  0.03314  0.03687
# 2505900000000  0.035702  0.03528  0.03186  0.04419  0.03339  0.03662
# 2506200000000  0.036736  0.03644  0.03278  0.04596  0.03436  0.03802
#
#                                   canonical memory usage           ...  \
#                     q95       std                   mean   median  ...
# end time                                                           ...
# 900000000      0.038340  0.002287               0.087198  0.08716  ...
# 1200000000     0.036512  0.002358               0.086914  0.08691  ...
# 1500000000     0.036214  0.002347               0.086879  0.08691  ...
# 1800000000     0.035912  0.002360               0.086869  0.08691  ...
# 2100000000     0.037402  0.002395               0.087110  0.08704  ...
# ...                 ...       ...                    ...      ...  ...
# 2505000000000  0.040818  0.002506               0.086642  0.08655  ...
# 2505300000000  0.040384  0.002328               0.086651  0.08667  ...
# 2505600000000  0.039272  0.002597               0.086642  0.08655  ...
# 2505900000000  0.040454  0.002911               0.086642  0.08655  ...
# 2506200000000  0.042044  0.003088               0.086642  0.08655  ...
#
#               cycles per instruction memory accesses per instruction  \
#                                  std                            mean
# end time
# 900000000                   0.116697                        0.004107
# 1200000000                  0.115363                        0.003897
# 1500000000                  0.118224                        0.003872
# 1800000000                  0.109008                        0.004027
# 2100000000                  0.133050                        0.004128
# ...                              ...                             ...
# 2505000000000               0.098550                        0.003809
# 2505300000000               0.099457                        0.003777
# 2505600000000               0.124989                        0.003708
# 2505900000000               0.133782                        0.003749
# 2506200000000               0.131300                        0.003711
#
#                                                                            \
#                  median       min       max       q25       q75       q95
# end time
# 900000000      0.004048  0.003306  0.004837  0.003902  0.004373  0.004750
# 1200000000     0.003928  0.003336  0.004458  0.003696  0.004089  0.004434
# 1500000000     0.003848  0.003275  0.004565  0.003654  0.004097  0.004468
# 1800000000     0.004051  0.003451  0.004576  0.003832  0.004215  0.004500
# 2100000000     0.004099  0.003269  0.004864  0.003732  0.004488  0.004728
# ...                 ...       ...       ...       ...       ...       ...
# 2505000000000  0.003778  0.003233  0.004333  0.003534  0.004131  0.004291
# 2505300000000  0.003819  0.003272  0.004504  0.003459  0.004003  0.004219
# 2505600000000  0.003671  0.003027  0.004423  0.003369  0.004039  0.004291
# 2505900000000  0.003605  0.003186  0.004761  0.003428  0.004182  0.004413
# 2506200000000  0.003598  0.002987  0.004773  0.003450  0.003905  0.004469
#
#                         Efficiency
#                     std
# end time
# 900000000      0.000411   0.481978
# 1200000000     0.000320   0.477496
# 1500000000     0.000350   0.476892
# 1800000000     0.000300   0.475728
# 2100000000     0.000462   0.477995
# ...                 ...        ...
# 2505000000000  0.000339   0.491919
# 2505300000000  0.000342   0.491032
# 2505600000000  0.000407   0.487893
# 2505900000000  0.000455   0.488857
# 2506200000000  0.000413   0.490708
#
# [8352 rows x 97 columns]

# %% [markdown]
# ### Scale values

# %%
values = readings_df.values

scaled, scaler = scale_values(values)

# %% [markdown]
# ### Create train-validation-test sets

# %%
n_train = int(scaled.shape[0] * 0.6)
n_validation = int(scaled.shape[0] * 0.2)
train = scaled[:n_train, :]
validation = scaled[n_train : (n_train + n_validation), :]
test = scaled[(n_train + n_validation) :, :]

print("Train shape:", train.shape)
print("Validation shape:", validation.shape)
print("Test shape:", test.shape)
# Out:
# Train shape: (5011, 97)
# Validation shape: (1670, 97)
# Test shape: (1671, 97)

# %% [markdown]
# ### Reshape the input data without Efficiency - __no_eff__

# %% [markdown]
# Reshape data, keeping out efficiency, that is our *target metric*, and according to the defined lookback and lookahead values, namely:
# - lookback: 24 sampling steps
# - lookahead: 3 sampling steps
#
# We perform the reshaping, using the `reshape_data` function present in the `gcd_data_manipulation.py` functions collector.

# %%
n_input = 24
n_out = 3

# %%
train_x, train_y = reshape_data(
    train, n_input, n_out, input_cols_interval=(0, -1)
)
print(train_x.shape, train_y.shape)

validation_x, validation_y = reshape_data(
    validation, n_input, n_out, input_cols_interval=(0, -1)
)
print(validation_x.shape, validation_y.shape)

test_x, test_y = reshape_data(
    test, n_input, n_out, input_cols_interval=(0, -1)
)
print(test_x.shape, test_y.shape)
# Out:
# (4985, 24, 96) (4985, 3)
# (1644, 24, 96) (1644, 3)
# (1645, 24, 96) (1645, 3)

# %% [markdown]
# ## Create AutoML

# %%
import autokeras as ak

# %%
clf = ak.TimeseriesForecaster(
    lookback=10,
    predict_from=1,
    predict_until=3,
    max_trials=1000,
    objective="val_loss",
)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./time_series_forecaster/oracle.json
# INFO:tensorflow:Reloading Oracle from existing project ./time_series_forecaster/oracle.json
# INFO:tensorflow:Reloading Tuner from ./time_series_forecaster/tuner0.json
# INFO:tensorflow:Reloading Tuner from ./time_series_forecaster/tuner0.json

# %%
(train[:,:-1].shape, train[:,-1:].shape)
# Out:
# ((5011, 96), (5011, 1))

# %%
clf.fit(
    x=train[:,:-1],
    y=train[:,-1:],
    validation_data=(validation[:,:-1], validation[:,-1:]),
    batch_size=72,
    epochs=10,
)
# Out:
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/10
# 70/70 [==============================] - 7s 55ms/step - loss: 0.1033 - mean_squared_error: 0.1033 - val_loss: 0.0766 - val_mean_squared_error: 0.0766
# Epoch 2/10
# 70/70 [==============================] - 3s 41ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 3/10
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0284 - val_mean_squared_error: 0.0284
# Epoch 4/10
# 70/70 [==============================] - 3s 41ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# Epoch 5/10
# 70/70 [==============================] - 3s 41ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0294 - val_mean_squared_error: 0.0294
# Epoch 6/10
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 7/10
# 70/70 [==============================] - 3s 41ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 8/10
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0349 - val_mean_squared_error: 0.0349
# Epoch 9/10
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# Epoch 10/10
# 70/70 [==============================] - 3s 40ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0312 - val_mean_squared_error: 0.0312
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./time_series_forecaster/best_model/assets
# INFO:tensorflow:Assets written to: ./time_series_forecaster/best_model/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff738228040> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff804d41070> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff77bb2f0a0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff9d020c760> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
predictions = clf.evaluate(test[:,:-1], test[:,-1:])

# %%
predictions
# Out:
# [0.03316894918680191, 0.03316894918680191]

# %%
model = clf.export_model()

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3, 96)]           0
#
#  bidirectional (Bidirectiona  (None, 3, 192)           148224
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 192)              221952
#  nal)
#
#  dropout (Dropout)           (None, 192)               0
#
#  regression_head_1 (Dense)   (None, 1)                 193
#
# =================================================================
# Total params: 370,369
# Trainable params: 370,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10, 96)]          0
#
#  bidirectional (Bidirectiona  (None, 10, 192)          148224
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 192)              221952
#  nal)
#
#  dropout (Dropout)           (None, 192)               0
#
#  regression_head_1 (Dense)   (None, 1)                 193
#
# =================================================================
# Total params: 370,369
# Trainable params: 370,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
try:
    model.save("../models/model_RNN_autokeras", save_format="tf")
except Exception:
    model.save("../models/model_RNN_autokeras.h5")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn, lstm_cell_14_layer_call_and_return_conditional_losses, lstm_cell_16_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/model_RNN_autokeras/assets
# INFO:tensorflow:Assets written to: ../models/model_RNN_autokeras/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff84447ad90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff844583310> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff8445b6220> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff8445b6a30> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
from tensorflow.keras.models import load_model

loaded_model = load_model("../models/model_RNN_autokeras", custom_objects=ak.CUSTOM_OBJECTS)

predicted_y = loaded_model.predict(np.reshape(test[:,:-1], (-1, 3, 96)))
print(predicted_y)
# Out:
# [[0.2764558 ]
#  [0.29620746]
#  [0.28091624]
#  [0.2691812 ]
#  [0.22745962]
#  [0.24441086]
#  [0.20272855]
#  [0.21055447]
#  [0.16711786]
#  [0.16060431]
#  [0.14870596]
#  [0.11562115]
#  [0.09691202]
#  [0.08014034]
#  [0.06676774]
#  [0.06144179]
#  [0.05975158]
#  [0.05754695]
#  [0.0582396 ]
#  [0.05616369]
#  [0.05429434]
#  [0.05914383]
#  [0.05843296]
#  [0.07525087]
#  [0.05927832]
#  [0.07121035]
#  [0.07477107]
#  [0.08462392]
#  [0.09197551]
#  [0.10930295]
#  [0.08755735]
#  [0.11701184]
#  [0.12049697]
#  [0.12788782]
#  [0.13186856]
#  [0.13091914]
#  [0.13474898]
#  [0.15629853]
#  [0.16664183]
#  [0.17257525]
#  [0.18780304]
#  [0.20215295]
#  [0.20794055]
#  [0.20848885]
#  [0.21648976]
#  [0.23052901]
#  [0.26287714]
#  [0.24024731]
#  [0.2361979 ]
#  [0.22266564]
#  [0.22698337]
#  [0.233658  ]
#  [0.24382862]
#  [0.22089922]
#  [0.2182265 ]
#  [0.22744805]
#  [0.24086131]
#  [0.24059294]
#  [0.22650367]
#  [0.23230006]
#  [0.23262252]
#  [0.2478397 ]
#  [0.25429302]
#  [0.2684115 ]
#  [0.23587473]
#  [0.23779011]
#  [0.2414823 ]
#  [0.24555105]
#  [0.23453034]
#  [0.23406363]
#  [0.2863043 ]
#  [0.28152576]
#  [0.2658525 ]
#  [0.27100012]
#  [0.26756403]
#  [0.28988796]
#  [0.28920648]
#  [0.27875188]
#  [0.2894419 ]
#  [0.30678168]
#  [0.30194733]
#  [0.30640662]
#  [0.29510105]
#  [0.63535184]
#  [0.6563499 ]
#  [0.5990368 ]
#  [0.56878704]
#  [0.5122112 ]
#  [0.48415837]
#  [0.4453592 ]
#  [0.404535  ]
#  [0.43059954]
#  [0.43014032]
#  [0.42671806]
#  [0.39364216]
#  [0.4126763 ]
#  [0.3683302 ]
#  [0.38614878]
#  [0.30138937]
#  [0.26222086]
#  [0.24555737]
#  [0.23966731]
#  [0.22681952]
#  [0.21748947]
#  [0.19843075]
#  [0.19283427]
#  [0.17315702]
#  [0.14882028]
#  [0.13229722]
#  [0.11454654]
#  [0.10772507]
#  [0.10597169]
#  [0.10326352]
#  [0.09957288]
#  [0.1068017 ]
#  [0.09280829]
#  [0.10577057]
#  [0.10884707]
#  [0.10304916]
#  [0.10284764]
#  [0.09250139]
#  [0.11359803]
#  [0.11142419]
#  [0.11426257]
#  [0.11825533]
#  [0.13149336]
#  [0.13494208]
#  [0.14395776]
#  [0.18308917]
#  [0.17842773]
#  [0.18845604]
#  [0.19568107]
#  [0.2079654 ]
#  [0.19986147]
#  [0.20533751]
#  [0.2305432 ]
#  [0.2320232 ]
#  [0.24309564]
#  [0.24006097]
#  [0.25463983]
#  [0.27563965]
#  [0.26655042]
#  [0.27342567]
#  [0.27084038]
#  [0.2684604 ]
#  [0.24784833]
#  [0.22948743]
#  [0.22226994]
#  [0.22048451]
#  [0.2175573 ]
#  [0.23359588]
#  [0.2283775 ]
#  [0.22919214]
#  [0.2350153 ]
#  [0.22938842]
#  [0.24773777]
#  [0.25449365]
#  [0.28316194]
#  [0.28229395]
#  [0.28867027]
#  [0.31272614]
#  [0.3005646 ]
#  [0.32500893]
#  [0.31811327]
#  [0.33365873]
#  [0.31079262]
#  [0.31067988]
#  [0.28656676]
#  [0.28156087]
#  [0.30359825]
#  [0.3004685 ]
#  [0.30100885]
#  [0.3006361 ]
#  [0.33696795]
#  [0.3205472 ]
#  [0.32840946]
#  [0.33511925]
#  [0.33030042]
#  [0.3195028 ]
#  [0.3174375 ]
#  [0.32409352]
#  [0.32584733]
#  [0.31431115]
#  [0.3125827 ]
#  [0.30702588]
#  [0.3188284 ]
#  [0.30698183]
#  [0.3118445 ]
#  [0.29554003]
#  [0.30559725]
#  [0.30721667]
#  [0.30796322]
#  [0.307808  ]
#  [0.31325603]
#  [0.31610927]
#  [0.30225563]
#  [0.29140335]
#  [0.26294515]
#  [0.24068776]
#  [0.21782276]
#  [0.209619  ]
#  [0.194951  ]
#  [0.16976771]
#  [0.16024837]
#  [0.14372692]
#  [0.12532204]
#  [0.10596208]
#  [0.11181747]
#  [0.1020169 ]
#  [0.10195612]
#  [0.09915341]
#  [0.10213083]
#  [0.10415024]
#  [0.10238615]
#  [0.08519109]
#  [0.10017893]
#  [0.09638442]
#  [0.11656275]
#  [0.10452959]
#  [0.13944635]
#  [0.13622697]
#  [0.14678007]
#  [0.14632715]
#  [0.15251763]
#  [0.16925104]
#  [0.1876043 ]
#  [0.17473936]
#  [0.17706595]
#  [0.19584057]
#  [0.20262067]
#  [0.21936421]
#  [0.21864752]
#  [0.24476151]
#  [0.24593186]
#  [0.2899768 ]
#  [0.29135638]
#  [0.29838035]
#  [0.30987433]
#  [0.2953389 ]
#  [0.2562418 ]
#  [0.23447731]
#  [0.24392535]
#  [0.2419622 ]
#  [0.26277566]
#  [0.25422186]
#  [0.25560287]
#  [0.26025772]
#  [0.26806912]
#  [0.24820569]
#  [0.2914478 ]
#  [0.26831067]
#  [0.283216  ]
#  [0.27294204]
#  [0.2868545 ]
#  [0.3111013 ]
#  [0.30661258]
#  [0.30471388]
#  [0.31058905]
#  [0.30178842]
#  [0.35669717]
#  [0.30077618]
#  [0.3420693 ]
#  [0.35150194]
#  [0.33911183]
#  [0.3317164 ]
#  [0.3535202 ]
#  [0.3285716 ]
#  [0.33916634]
#  [0.32839483]
#  [0.33687177]
#  [0.32667175]
#  [0.3403581 ]
#  [0.3329666 ]
#  [0.32814083]
#  [0.31325385]
#  [0.33195302]
#  [0.3169341 ]
#  [0.34618926]
#  [0.3302507 ]
#  [0.3475146 ]
#  [0.32540295]
#  [0.33114612]
#  [0.32599017]
#  [0.31894588]
#  [0.3173468 ]
#  [0.3225    ]
#  [0.3125978 ]
#  [0.30039605]
#  [0.3116685 ]
#  [0.30086803]
#  [0.28393108]
#  [0.3075788 ]
#  [0.3062714 ]
#  [0.30658612]
#  [0.28418493]
#  [0.2653943 ]
#  [0.24445173]
#  [0.23960121]
#  [0.20083666]
#  [0.17598441]
#  [0.15817465]
#  [0.1444822 ]
#  [0.14274491]
#  [0.13228433]
#  [0.10260773]
#  [0.09498497]
#  [0.07828865]
#  [0.08584347]
#  [0.08205624]
#  [0.09856415]
#  [0.09322887]
#  [0.09148209]
#  [0.07823062]
#  [0.07821853]
#  [0.09106011]
#  [0.08621834]
#  [0.10795699]
#  [0.11870328]
#  [0.12282271]
#  [0.13029607]
#  [0.13361575]
#  [0.15752684]
#  [0.16446418]
#  [0.18512811]
#  [0.19613557]
#  [0.21958186]
#  [0.23547453]
#  [0.24389437]
#  [0.27462426]
#  [0.301921  ]
#  [0.28687933]
#  [0.28738958]
#  [0.28563645]
#  [0.29517016]
#  [0.2982695 ]
#  [0.3035431 ]
#  [0.28036508]
#  [0.288373  ]
#  [0.29930633]
#  [0.2898379 ]
#  [0.2991932 ]
#  [0.29622683]
#  [0.29427642]
#  [0.28559214]
#  [0.29086053]
#  [0.29807964]
#  [0.2915004 ]
#  [0.2913056 ]
#  [0.2626762 ]
#  [0.2640243 ]
#  [0.28072456]
#  [0.288275  ]
#  [0.27827585]
#  [0.27294078]
#  [0.27042633]
#  [0.281616  ]
#  [0.28510848]
#  [0.27832296]
#  [0.28880677]
#  [0.2892553 ]
#  [0.28365916]
#  [0.28508356]
#  [0.293802  ]
#  [0.29560494]
#  [0.29287902]
#  [0.27906466]
#  [0.28634015]
#  [0.30860826]
#  [0.2865671 ]
#  [0.30460465]
#  [0.32307595]
#  [0.3033681 ]
#  [0.3008868 ]
#  [0.30487677]
#  [0.3062636 ]
#  [0.30262497]
#  [0.29949683]
#  [0.31491554]
#  [0.29864383]
#  [0.29785898]
#  [0.31543034]
#  [0.3126558 ]
#  [0.30696207]
#  [0.30556172]
#  [0.28594756]
#  [0.27474383]
#  [0.2705278 ]
#  [0.27178472]
#  [0.26841936]
#  [0.28569773]
#  [0.28319204]
#  [0.26085672]
#  [0.22702345]
#  [0.2287937 ]
#  [0.19711302]
#  [0.17592037]
#  [0.1676993 ]
#  [0.16375713]
#  [0.1224668 ]
#  [0.12502898]
#  [0.12701355]
#  [0.11353739]
#  [0.08899605]
#  [0.09414206]
#  [0.08152614]
#  [0.11079175]
#  [0.08363075]
#  [0.08874898]
#  [0.07793796]
#  [0.08356945]
#  [0.08959921]
#  [0.0897242 ]
#  [0.10046752]
#  [0.11026068]
#  [0.08426933]
#  [0.09987702]
#  [0.11964341]
#  [0.13618068]
#  [0.14982381]
#  [0.15851209]
#  [0.1772182 ]
#  [0.19886799]
#  [0.2037296 ]
#  [0.24063914]
#  [0.25145325]
#  [0.26752493]
#  [0.28721243]
#  [0.28889087]
#  [0.29575697]
#  [0.28340763]
#  [0.29902688]
#  [0.2812519 ]
#  [0.27987012]
#  [0.27611533]
#  [0.29215926]
#  [0.3075058 ]
#  [0.26177576]
#  [0.27819082]
#  [0.27211317]
#  [0.27842444]
#  [0.27460542]
#  [0.28285524]
#  [0.28495583]
#  [0.27987498]
#  [0.28563458]
#  [0.27547184]
#  [0.2832553 ]
#  [0.28654033]
#  [0.2927714 ]
#  [0.2896314 ]
#  [0.2861834 ]
#  [0.28528145]
#  [0.28961453]
#  [0.3235121 ]
#  [0.29149997]
#  [0.318487  ]
#  [0.28889275]
#  [0.30185628]
#  [0.3002174 ]
#  [0.30420816]
#  [0.3035431 ]
#  [0.30432692]
#  [0.30289146]
#  [0.27803507]
#  [0.28051555]
#  [0.29348907]
#  [0.2760951 ]
#  [0.30587962]
#  [0.31793353]
#  [0.3252633 ]
#  [0.33167693]
#  [0.31828743]
#  [0.31003824]
#  [0.31818235]
#  [0.3215119 ]
#  [0.33967987]
#  [0.32320586]
#  [0.3209236 ]
#  [0.30952638]
#  [0.3361084 ]
#  [0.34509367]
#  [0.3458018 ]
#  [0.32893288]
#  [0.3686509 ]
#  [0.31830537]
#  [0.2836754 ]
#  [0.2733979 ]
#  [0.27330953]
#  [0.23733483]
#  [0.23418799]
#  [0.22530389]
#  [0.21107307]
#  [0.16529767]
#  [0.1626713 ]
#  [0.12829407]
#  [0.11447679]
#  [0.11965673]
#  [0.1032342 ]
#  [0.10185574]
#  [0.10795099]
#  [0.10774675]
#  [0.10936999]
#  [0.10921961]
#  [0.10608498]
#  [0.09798294]
#  [0.09088022]
#  [0.08984908]
#  [0.09232644]
#  [0.09851256]
#  [0.12152808]
#  [0.08863464]
#  [0.11198777]
#  [0.1271753 ]
#  [0.127805  ]
#  [0.14038454]
#  [0.16087516]
#  [0.1685844 ]
#  [0.1949987 ]
#  [0.19589135]
#  [0.21010734]
#  [0.23700312]
#  [0.2593505 ]
#  [0.27657092]
#  [0.2894187 ]
#  [0.30872706]
#  [0.29032978]
#  [0.3078328 ]
#  [0.28106564]
#  [0.29686287]
#  [0.28902143]
#  [0.28643787]
#  [0.26973966]
#  [0.2823906 ]
#  [0.2522296 ]
#  [0.26554772]
#  [0.24680077]
#  [0.25221744]
#  [0.2830915 ]
#  [0.25619143]
#  [0.29834846]
#  [0.3194445 ]
#  [0.3359415 ]
#  [0.3498127 ]
#  [0.37873408]
#  [0.38057715]
#  [0.3539973 ]
#  [0.33976683]
#  [0.32721388]
#  [0.30843788]
#  [0.3066801 ]
#  [0.29248902]
#  [0.30464327]
#  [0.3240371 ]
#  [0.30998334]
#  [0.34530625]
#  [0.32832247]
#  [0.31018442]]
